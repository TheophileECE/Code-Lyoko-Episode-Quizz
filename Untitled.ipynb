# %%
import random

# Episode data stored as a dictionary
episodes = {
    1: {"fr": "Teddygozilla", "en": "Teddygozilla"},
    2: {"fr": "Le voir pour le croire", "en": "Seeing Is Believing"},
    3: {"fr": "Vacances dans la brume", "en": "Holiday in the Fog"},
    4: {"fr": "Carnet de bord", "en": "Log Book"},
    5: {"fr": "Big bogue", "en": "Big Bug"},
    6: {"fr": "Cruel dilemme", "en": "Cruel Dilemma"},
    7: {"fr": "Problème d'image", "en": "Image Problem"},
    8: {"fr": "Clap de fin", "en": "End of Take"},
    9: {"fr": "Satellite", "en": "Satellite"},
    10: {"fr": "Créature de rêve", "en": "The Girl of the Dreams"},
    11: {"fr": "Enragés", "en": "Plagued"},
    12: {"fr": "Attaque en piqué", "en": "Swarming Attack"},
    13: {"fr": "D'un cheveu", "en": "Just in Time"},
    14: {"fr": "Piège", "en": "The Trap"},
    15: {"fr": "Crise de rire", "en": "Laughing Fit"},
    16: {"fr": "Claustrophobie", "en": "Claustrophobia"},
    17: {"fr": "Mémoire morte", "en": "Amnesia"},
    18: {"fr": "Musique mortelle", "en": "Killer Music"},
    19: {"fr": "Frontière", "en": "Frontier"},
    20: {"fr": "L'âme des robots", "en": "The Robots"},
    21: {"fr": "Gravité zéro", "en": "Zero Gravity Zone"},
    22: {"fr": "Routine", "en": "Routine"},
    23: {"fr": "36ème dessous", "en": "Rock Bottom?"},
    24: {"fr": "Canal fantôme", "en": "Ghost Channel"},
    25: {"fr": "Code Terre", "en": "Code: Earth"},
    26: {"fr": "Faux départ", "en": "False Start"},
    27: {"fr": "Nouvelle donne", "en": "New Order"},
    28: {"fr": "Terre inconnue", "en": "Uncharted Territory"},
    29: {"fr": "Exploration", "en": "Exploration"},
    30: {"fr": "Un grand jour", "en": "A Great Day"},
    31: {"fr": "Mister Pück", "en": "Mister Pück"},
    32: {"fr": "Saint Valentin", "en": "Saint Valentine's Day"},
    33: {"fr": "Mix final", "en": "Final Mix"},
    34: {"fr": "Chaînon manquant", "en": "Missing Link"},
    35: {"fr": "Les jeux sont faits", "en": "The Chips Are Down"},
    36: {"fr": "Marabounta", "en": "Marabounta"},
    37: {"fr": "Intérêt commun", "en": "Common Interest"},
    38: {"fr": "Tentation", "en": "Temptation"},
    39: {"fr": "Mauvaise conduite", "en": "A Bad Turn"},
    40: {"fr": "Contagion", "en": "Attack of the Zombies"},
    41: {"fr": "Ultimatum", "en": "Ultimatum"},
    42: {"fr": "Désordre", "en": "A Fine Mess"},
    43: {"fr": "Mon meilleur ennemi", "en": "XANA's Kiss"},
    44: {"fr": "Vertige", "en": "Vertigo"},
    45: {"fr": "Guerre froide", "en": "Cold War"},
    46: {"fr": "Empreintes", "en": "Déjà Vu"},
    47: {"fr": "Au meilleur de sa forme", "en": "Tip-Top Shape"},
    48: {"fr": "Esprit frappeur", "en": "Is There Anybody Out There?"},
    49: {"fr": "Franz Hopper", "en": "Franz Hopper"},
    50: {"fr": "Contact", "en": "Contact"},
    51: {"fr": "Révélation", "en": "Revelation"},
    52: {"fr": "Réminiscence", "en": "The Key"},
    53: {"fr": "Droit au coeur", "en": "Straight to Heart"},
    54: {"fr": "Lyoko moins un", "en": "Lyoko Minus One"},
    55: {"fr": "Raz de marée", "en": "Tidal Wave"},
    56: {"fr": "Fausse piste", "en": "False Lead"},
    57: {"fr": "Aelita", "en": "Aelita"},
    58: {"fr": "Le prétendant", "en": "The Pretender"},
    59: {"fr": "Le secret", "en": "The Secret"},
    60: {"fr": "Tarentule au plafond", "en": "Temporary Insanity"},
    61: {"fr": "Sabotage", "en": "Sabotage"},
    62: {"fr": "Désincarnation", "en": "Nobody in Particular"},
    63: {"fr": "Triple sot", "en": "Triple Trouble"},
    64: {"fr": "Surmenage", "en": "Double Trouble"},
    65: {"fr": "Dernier round", "en": "Final Round"},
    66: {"fr": "Renaissance", "en": "William Returns"},
    67: {"fr": "Mauvaise réplique", "en": "Double Take"},
    68: {"fr": "Première partie", "en": "Opening Act"},
    69: {"fr": "Double foyer", "en": "Wreck Room"},
    70: {"fr": "Skidbladnir", "en": "Skidbladnir"},
    71: {"fr": "Premier voyage", "en": "Maiden Voyage"},
    72: {"fr": "Leçon de choses", "en": "Crash Course"},
    73: {"fr": "Réplika", "en": "Replika"},
    74: {"fr": "Je préfère ne pas en parler !", "en": "I'd Rather Not Talk About It"},
    75: {"fr": "Corps céleste", "en": "Hot Shower"},
    76: {"fr": "Le lac", "en": "The Lake"},
    77: {"fr": "Torpilles virtuelles", "en": "Lost at Sea"},
    78: {"fr": "Expérience", "en": "Lab Rat"},
    79: {"fr": "Arachnophobie", "en": "Bragging Rights"},
    80: {"fr": "Kiwodd", "en": "Dog Day Afternoon"},
    81: {"fr": "Oeil pour oeil", "en": "A Lack of Goodwill"},
    82: {"fr": "Mémoire blanche", "en": "Distant Memory"},
    83: {"fr": "Superstition", "en": "Hard Luck"},
    84: {"fr": "Missile guidé", "en": "Guided Missile"},
    85: {"fr": "La belle de Kadic", "en": "Kadic Bombshell"},
    86: {"fr": "Kiwi superstar", "en": "Canine Conundrum"},
    87: {"fr": "Planète bleue", "en": "A Space Oddity"},
    88: {"fr": "Cousins ennemis", "en": "Cousins Once Removed"},
    89: {"fr": "Il est sensé d'être insensé", "en": "Music to Soothe the Savage Beast"},
    90: {"fr": "Médusée", "en": "Wrong Exposure"},
    91: {"fr": "Mauvaises ondes", "en": "Bad Connection"},
    92: {"fr": "Sueurs froides", "en": "Cold Sweat"},
    93: {"fr": "Retour", "en": "Down to Earth"},
    94: {"fr": "Contre-attaque", "en": "Fight to the Finish"},
    95: {"fr": "Souvenirs", "en": "Echoes"}
}

# Function to allow the user to select how many questions they want
def choose_language():
    while True:
        print("Choose your language:")
        print("1. French")
        print("2. English")
        choice = input("Please enter 1 or 2: ")

        if choice == '1':
            return 'fr'
        elif choice == '2':
            return 'en'
        else:
            print("Invalid choice. Please select 1 or 2.")

# Function to allow the user to select how many questions they want
def choose_question_count():
    while True:
        print("How many questions would you like to answer?")
        print("1. 10 questions")
        print("2. 20 questions")
        print("3. All questions")
        choice = input("Please enter 1, 2, or 3: ")

        if choice == '1':
            return 10
        elif choice == '2':
            return 20
        elif choice == '3':
            return len(episodes)
        else:
            print("Invalid choice. Please select 1, 2, or 3.")

# Function to run the quiz
def run_quiz():
    # Let the user choose the language
    language = choose_language()

    # Let the user choose how many questions they want
    total_questions = choose_question_count()

    score = 0

    # Shuffle the episodes for randomness
    episode_numbers = list(episodes.keys())
    random.shuffle(episode_numbers)

    # Use only the selected number of questions
    selected_episodes = episode_numbers[:total_questions]

    for episode_num in selected_episodes:
        # Display the episode title in the chosen language
        episode_title = episodes[episode_num][language]
        print(f"\nWhich episode number is titled: '{episode_title}'?")

        # Get user input
        user_input = input("Enter the episode number: ")

        # Validate input
        if user_input.isdigit():
            user_input = int(user_input)

            # Check if the answer is correct
            if user_input == episode_num:
                print("Correct!")
                score += 1
            else:
                print(f"Incorrect. The correct number is #{episode_num}.")
        else:
            print("Please enter a valid number.")

    # After all selected questions are answered, show the final score
    print(f"\nQuiz completed! Your final score is {score} out of {total_questions}.")

# Start the quiz
run_quiz()
